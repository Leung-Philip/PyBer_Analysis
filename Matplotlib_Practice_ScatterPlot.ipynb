# %%
import matplotlib.pyplot as plt

# %%
x = [50,42,39,34,32,48,22,17,8,13]
y = [17,19,21,22,24,23,34,61,43,35]

# %%
plt.scatter(x,y, c ='green', marker = 'x', s = x)
plt.xlabel('Total Number of Rides (Per City)')
plt.ylabel('Average Fare ($)')
plt.title('Average Fare vs Total Rides')
plt.show()

# %%
#Scatter with MATLAB

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis,y_axis,'o')

# %%
plt.scatter(y_axis,x_axis, c='r', label = 'Chicago')
plt.legend()
plt.title('Pyber Fare by Month')
plt.xlabel('Fare($)')
plt.ylabel('Date')
plt.xlim(0,50)
plt.gca().invert_yaxis()

# %%
#Bubble Chart
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
plt.scatter(x_axis,y_axis, s=y_axis_larger)

# %%
# using list comprehension to refactor the code above
plt.scatter(x_axis,y_axis, s = [i * 3 for i in y_axis])

# %%
#Scatter plot with object oriented interface
fig, ax = plt.subplots()
ax.scatter(x_axis,y_axis)

# %%
#Bubble chart with object oriented interface
fig, ax = plt.subplots()
ax.scatter(y_axis,x_axis, s = [i * 5 for i in y_axis], c = 'skyblue', label = ' Boston', linewidth = 2, edgecolors = 'black', alpha = 0.8
)
ax.legend()
ax.set_title('Pyber Fare by Month')
ax.set_xlabel('Fare($)')
ax.set_ylabel('Date')
ax.set_xlim(0,50)
ax.invert_yaxis()
